# %% [markdown]
# ## Data Analysis : Weather Dataset
#
# The Weather Dataset is a time-series dataset with information about weather conditons at a particular locations.
# It has Temp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir, WindSpeed, Humidity, Pressure,
# Cloud,RainToday, RainTomorrow.

# %%
#importing library

import pandas as pd

# %%
#importing csv file

weather_data = pd.read_csv("weather.csv")

# %%
#printing data

weather_data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#gives first 5 rows of dataframe

weather_data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#shows total number of rows and columns

weather_data.shape
# Out:
# (366, 22)

# %%
#shows the index of dataframe

weather_data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
#shows the columns of the dataframe

weather_data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#shows the data-type of data in different columns of dataset

weather_data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
#shows unique value in a partcular columns

weather_data["MinTemp"].unique()
# Out:
# array([ 8. , 14. , 13.7, 13.3,  7.6,  6.2,  6.1,  8.3,  8.8,  8.4,  9.1,
#         8.5, 10.1, 12.1, 12.4, 13.8, 11.7, 15.6, 15.3, 16.4, 12.8, 12. ,
#        15.4, 12.9, 15.1, 13.6, 11.6, 16.6, 14.5, 16.3, 17.2, 16.5, 15. ,
#        14.9, 11.8,  9.6,  8.9, 15.5, 10.8,  7.5, 12.6, 14.8, 19.9,  9.2,
#        11.3,  9.8, 14.3, 14.4, 15.9, 16.7, 17.5, 14.7, 20.9, 17. , 16. ,
#        17.9, 15.2, 10. ,  9.9, 10.3, 12.7, 13.2, 18. , 17.6, 17.1, 18.2,
#        16.8, 10.4,  8.6, 11.2, 11.4, 11.5, 13. ,  7.7,  4.4,  7.4,  9.5,
#        12.5, 13.9, 12.3, 13.1,  7.1,  4.2,  3.5,  5.3,  7. ,  0.4,  3.2,
#         5.9,  8.1,  6.9,  5.6,  7.2,  5.4,  6.3,  7.9,  2.4,  2.5,  5. ,
#         3.8,  4.3, -2.1, -1.8,  2.1,  0.5, -0.9, -0.2,  0.1,  1.5,  9.4,
#         1.3,  2.2, -0.4,  4.5, -2.7,  0.3,  1.2, -0.3,  4.7,  4.9,  1.4,
#        -0.1,  0.6,  4.6, 10.6,  7.8, 10.2,  7.3,  8.7,  1. ,  6.4,  4. ,
#         0.9,  0.8, -1.5,  6.6, -1.6, -3.1, -0.6,  3. ,  2.9, -1.3,  1.8,
# ...

# %%
#shows number of unique value in different columns

weather_data.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
#shows total number of non - null values

weather_data.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
#shows all unique values with the number of times it ocurred in a particular columns

weather_data["MinTemp"].value_counts()
# Out:
# 0.5     6
# 4.4     6
# 15.1    5
# 3.2     5
# 2.3     5
#        ..
# 13.9    1
# 9.5     1
# 7.7     1
# 11.4    1
# 3.3     1
# Name: MinTemp, Length: 180, dtype: int64

# %%
#Information

weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## All unique "RAINFALL" values in data.

# %%
weather_data["Rainfall"].unique()
# Out:
# array([ 0. ,  3.6, 39.8,  2.8,  0.2, 16.2,  1.2,  0.6,  0.4, 25.8, 22.6,
#         4.2,  6.6,  4. ,  5.4,  1.4,  3.4,  6.4, 11. , 17.4, 14.4,  2. ,
#         4.8, 18.8, 12.2,  0.8,  5.2,  2.2,  1.8,  9. ,  1. ,  4.4, 10.4,
#         3. , 19.8,  2.6,  7.2,  3.8,  6.2, 16.8,  1.6, 19.2,  7.4,  9.8,
#         7.6,  8.2, 13.2])

# %% [markdown]
# ## Number of times when "it will Rain Tomorrow".

# %%
len(weather_data.groupby("RainTomorrow").get_group("Yes"))
# Out:
# 66

# %% [markdown]
# ## Number of times when the Wind Speed at 9AM was 6 KM/h

# %%
weather_data["WindSpeed9am"].value_counts()[6]
# Out:
# 76

# %% [markdown]
# ## Find all null values in the dataframe

# %%
weather_data.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %% [markdown]
# ## Mean of MinTemp and MaxTemp

# %%
weather_data['MinTemp'].mean()
# Out:
# 7.265573770491811

# %%
weather_data['MaxTemp'].mean()
# Out:
# 20.55027322404372

# %% [markdown]
# ## Standard deviation of Wind Gust Speed

# %%
weather_data['WindGustSpeed'].std()
# Out:
# 13.059807144421082

# %% [markdown]
# ## Variance of Evaporation

# %%
weather_data["Evaporation"].var()
# Out:
# 7.12560311400555

# %% [markdown]
# ## All instances when it "Rained Today"

# %%
weather_data[weather_data["RainToday"].str.contains("Yes")]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 339     10.3     21.3       3.0          4.2       6.7         NNW
# 341      0.3     16.0       8.2          5.4      11.8          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# ...

# %% [markdown]
# ## All instances when the evaporation is below 5 and sunshine is  7

# %%
weather_data[(weather_data['Evaporation']<5)& (weather_data['Sunshine']==7)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 181     -1.8     14.8       0.0          1.4       7.0           N
# 247     -0.1     14.2       0.0          1.4       7.0           W
# 295     -0.6     12.2       0.0          2.6       7.0           S
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 181           28.0          E          N           2.0  ...           40
# 247           13.0        NaN        WNW           NaN  ...           55
# 295           59.0          S          S          15.0  ...           44
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 181       1024.2       1020.5         1         7      5.3     13.9
# 247       1032.9       1028.9         1         2      4.7     12.6
# 295       1018.5       1016.8         8         5      6.9     10.7
#
#      RainToday  RISK_MM RainTomorrow
# 181         No      0.0           No
# 247         No      0.0           No
# ...

# %% [markdown]
# ## Mean Value of each column against "Evaporation"

# %%
weather_data.groupby("Evaporation").mean()
# Out:
#                MinTemp    MaxTemp  Rainfall   Sunshine  WindGustSpeed  \
# Evaporation
# 0.2          10.400000  15.050000  4.300000   1.550000      43.500000
# 0.6           4.620000  14.000000  1.120000   3.120000      29.000000
# 0.8          -0.300000  11.000000  0.500000   6.300000      46.250000
# 1.0           1.833333  14.066667  0.000000   2.066667      19.666667
# 1.2           4.037500  16.750000  0.750000   8.157143      28.750000
# 1.4           1.720000  13.026667  2.213333   6.533333      34.800000
# 1.6           3.746154  16.553846  0.953846   7.438462      32.692308
# 1.8           1.550000  13.428571  1.928571   5.150000      43.384615
# 2.0           3.120000  16.740000  0.400000   6.200000      26.666667
# 2.2           2.100000  15.490476  0.876190   6.766667      33.809524
# 2.4           2.227273  16.400000  2.181818   6.490909      35.636364
# 2.6           3.535714  15.428571  2.042857   7.371429      38.357143
# ...

# %% [markdown]
# ## All instances where the Windspeed at 9am is > 10 or Windspeed at 3pm is > 10 and Wind Gust Speed is > 40

# %%
((weather_data["WindSpeed9am"]>10)| (weather_data["WindSpeed3pm"]>10)& (weather_data["WindSpeed9am"]>40))
